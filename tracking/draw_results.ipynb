# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 

 


plt.scatter(60.3,43.1,s=100,c="green",marker='P', label="Atom")
plt.scatter(52.8,44.5,s=100,c="blue",marker='v', label="Dimp")
plt.scatter(39.3,47.1,s=100,c="gold",marker='s', label="Super Dimp")
plt.scatter(32.8,45.8,s=100,c="brown",marker='D', label="KYS")
plt.scatter(17.2,48.6,s=100,c="purple",marker='h', label="Keep Track")
plt.scatter(27.0,47.4,s=100,c="pink",marker='X', label="Stark")
plt.scatter(24.9,49.6,s=100,c="orange",marker='*', label="Tomp101")
plt.scatter(31.0,49.8,s=100,c="slateblue",marker='>', label="OSTrack384")
plt.scatter(22.3,51.8,s=100,c="springgreen",marker='o', label="TransMDOT-Single")
plt.scatter(13.3,53.3,s=100,c="red",marker='H', label="ASNet-Fusion")
plt.scatter(22.3,63.5,s=100,c="red",marker='o', label="TransMDOT-Fusion")


plt.xlabel("Speed(fps)")
plt.ylabel("Success Score(%)")
plt.title("Visualization of Success Score and Speed on Three-MDOT Dataset", fontsize=10)

plt.xlim()
plt.ylim()

plt.legend()
plt.grid(ls='--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 

 


plt.scatter(64.1,39.6,s=100,c="green",marker='P', label="Atom")
plt.scatter(49.3,42.8,s=100,c="blue",marker='v', label="Dimp")
plt.scatter(36.4,43.6,s=100,c="gold",marker='s', label="Super Dimp")
plt.scatter(30.8,42.0,s=100,c="brown",marker='D', label="KYS")
plt.scatter(16.6,43.2,s=100,c="purple",marker='h', label="Keep Track")
plt.scatter(28.0,44.5,s=100,c="pink",marker='X', label="Stark")
plt.scatter(25.2,44.6,s=100,c="orange",marker='*', label="Tomp101")
plt.scatter(31.3,49.0,s=100,c="slateblue",marker='>', label="OSTrack384")
plt.scatter(26.6,50.8,s=100,c="springgreen",marker='o', label="TransMDOT-Single")
plt.scatter(18.5,48.2,s=100,c="red",marker='H', label="ASNet-Fusion")
plt.scatter(26.6,59.0,s=100,c="red",marker='o', label="TransMDOT-Fusion")


plt.xlabel("Speed(fps)")
plt.ylabel("Success Score(%)")
plt.title("Visualization of Success Score and Speed on Two-MDOT Dataset", fontsize=10)

plt.xlim()
plt.ylim()

plt.yticks(np.arange(39, 60, step=2.5))

plt.legend()
plt.grid(ls='--')
plt.show()
